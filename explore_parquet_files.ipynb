# %%
import pandas as pd

# Lese die Parquet-Datei
df = pd.read_parquet("lichess_moves_final.parquet")

# Zeige die ersten 10 Zeilen an
print(df.head(10))

print(df.loc[0, 'BaseFEN'])
# Out:
#                                              BaseFEN  PlayerEloBucket MoveSAN  \
# 0  r1bqkb1r/ppp1pp2/2n2n1p/3p2p1/3P1B2/2P1PN2/PP3...             1000     Bg3
# 1  rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...             1000     Nf6
# 2  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...             1000      c6
# 3  r1bqkb1r/p1pp1ppp/2p2n2/8/4P3/2N5/PPP2PPP/R1BQ...             1000      d5
# 4  rn1qkbnr/pbpppppp/1p6/8/3PP3/2N5/PPP2PPP/R1BQK...             1000      c5
# 5  r1bqkbnr/ppp2ppp/2n5/3pp3/2PP4/5N2/PP2PPPP/RNB...             1000    dxe5
# 6  rn3bnr/ppp2kpp/5q2/4p3/4P1Q1/8/PPPP1PPP/RNB1K2...             1000     O-O
# 7  r1bqkb1r/pp1p1ppp/2n1pn2/2p5/4PP2/2N2N2/PPPP2P...             1000     Bc4
# 8  rnbqkbnr/ppp1pppp/8/3N4/3pP3/8/PPPP1PPP/R1BQKB...             1000      e5
# 9  r1bqk1nr/pppp1ppp/2n5/2b1p3/3PP3/2N2N2/PPP2PPP...             1000    exd4
#
#    TimesPlayed
# 0           38
# 1        62437
# 2        86231
# 3          118
# 4           71
# 5           37
# 6            3
# 7            8
# 8          702
# 9          788
# r1bqkb1r/ppp1pp2/2n2n1p/3p2p1/3P1B2/2P1PN2/PP3PPP/RN1QKB1R w KQkq -
